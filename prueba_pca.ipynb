# %%
from Paquetes.dimensionality_reduction import PCAStudy

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler,MinMaxScaler,MaxAbsScaler,RobustScaler
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder
train = pd.read_csv("./data/train.csv")
test = pd.read_csv("./data/test.csv")
sample = pd.read_csv("./data/sample_submission.csv")

# %%
pc = PCAStudy(data =train , encoder = OneHotEncoder(), pca_components = 2 , num_transformer = StandardScaler(),verbose  = 1)
pc2 = PCAStudy(data =train , encoder = OneHotEncoder(), pca_components = 2 ,verbose  = 0)

# %%
pc.num_transformer
# Out:
# StandardScaler()

# %%
pc.num_transformer = MinMaxScaler()

# %%
pc.num_transformer
# Out:
# MinMaxScaler()

# %%
pc.plot_variance_retained
pc.study_case
pc.plot_variance_retained
# Out:
# Error in method plot_variance_retained : PCA not fitted, call study_case method first
# combinations [(OneHotEncoder(), MinMaxScaler(), 2)]
# Columns with NA  []
# No NA values in the dataframe
# Numero de features tras step ColumnTransformer(remainder='passthrough',
#                   transformers=[('encoder', OneHotEncoder(),
#                                  ['Drug', 'Sex', 'Ascites', 'Hepatomegaly',
#                                   'Spiders', 'Edema', 'Status'])]):  29
# Numero de features tras step MinMaxScaler():  29
# -----------------------------------------------------------------
# Number of PCA components choosen after using OneHotEncoder(): 2
# Explained variance ratio:
#  [0.31358509 0.18974416]
# Fraction of original variance (or information) kept by each principal component axis (or image vector) after apllying OneHotEncoder() : 0.503
# -----------------------------------------------------------------

# %%
pc.results
# Out:
#            ENCODER ORIGINAL_FEATURES ENCODED_FEATURES NUMERICAL_TRANSFORMER  \
# 0  OneHotEncoder()                20               29        MinMaxScaler()
#
#   PCA_COMPONENTS ORIGINAL_VARIANCE_RETAINED
# 0              2                   0.503329

# %%
pc2.verbose = 1
pc2.study_case
# Out:
# combinations [(OneHotEncoder(), 2)]
# Columns with NA  []
# No NA values in the dataframe
# Numero de features tras step ColumnTransformer(remainder='passthrough',
#                   transformers=[('encoder', OneHotEncoder(),
#                                  ['Drug', 'Sex', 'Ascites', 'Hepatomegaly',
#                                   'Spiders', 'Edema', 'Status'])]):  29
# -----------------------------------------------------------------

# %%
pc2.plot_variance_retained
# Out:
# Number of PCA components choosen after using OneHotEncoder(): 2
# Explained variance ratio:
#  [0.57388384 0.22040909]
# Fraction of original variance (or information) kept by each principal component axis (or image vector) after apllying OneHotEncoder() : 0.794
# -----------------------------------------------------------------

# %%
pc2.results
# Out:
#            ENCODER ORIGINAL_FEATURES ENCODED_FEATURES NUMERICAL_TRANSFORMER  \
# 0  OneHotEncoder()                20               29                  None
#
#   PCA_COMPONENTS ORIGINAL_VARIANCE_RETAINED
# 0              2                   0.794293

# %%
pc2.num_transformer = StandardScaler()

# %%
pc2.study_case
# Out:
# combinations [(OneHotEncoder(), StandardScaler(), 2)]
# Columns with NA  []
# No NA values in the dataframe
# Numero de features tras step ColumnTransformer(remainder='passthrough',
#                   transformers=[('encoder', OneHotEncoder(),
#                                  ['Drug', 'Sex', 'Ascites', 'Hepatomegaly',
#                                   'Spiders', 'Edema', 'Status'])]):  29
# Numero de features tras step StandardScaler():  29
# -----------------------------------------------------------------

# %%
pc2.results
# Out:
#            ENCODER ORIGINAL_FEATURES ENCODED_FEATURES NUMERICAL_TRANSFORMER  \
# 0  OneHotEncoder()                20               29      StandardScaler()
#
#   PCA_COMPONENTS ORIGINAL_VARIANCE_RETAINED
# 0              2                    0.30044

# %%
pc2.encoder
# Out:
# OneHotEncoder()

# %%
pc2.num_transformer
# Out:
# StandardScaler()

# %%
pc2.plot_feature_weights
# Out:
# Eigenvectors :
#  [[ 0.00104382 -0.00104382 -0.05892306  0.05892306 -0.25012169  0.25012169
#   -0.25090407  0.25090407 -0.22423531  0.22423531 -0.25036687  0.11857754
#    0.23076839 -0.28307492  0.01323272  0.28428523  0.00441715 -0.2019457
#    0.09171393  0.25279348  0.07653605 -0.20116106  0.22197284  0.07417287
#    0.15643801  0.11908699 -0.1182026   0.20829488  0.20028208]
#  [ 0.27737594 -0.27737594  0.06414536 -0.06414536 -0.38314133  0.38314133
#    0.26100273 -0.26100273  0.08097336 -0.08097336 -0.27814082  0.0534852
#    0.34021478  0.14198864 -0.08321476 -0.11291227  0.00621232  0.0409315
#    0.10032983 -0.04279238 -0.24048648 -0.05689377 -0.07629214 -0.0845731
#   -0.17522566 -0.12874089 -0.05828413  0.0275739  -0.14159382]]

# %%
pc.plot_feature_weights
# Out:
# Eigenvectors :
#  [[-2.66585038e-02  2.66585038e-02 -3.02402037e-02  3.02402037e-02
#   -8.59834076e-02  8.59834076e-02 -4.46748484e-01  4.46748484e-01
#   -2.96873105e-01  2.96873105e-01 -1.38269220e-01  5.69332818e-02
#    8.13359387e-02 -4.01957493e-01  1.03304098e-02  3.91627083e-01
#    2.34461375e-03 -1.05340812e-01  3.66868795e-02  7.16173735e-02
#    2.17047221e-02 -5.42744187e-02  6.14570321e-02  2.52549807e-02
#    3.87807014e-02  2.20468972e-02 -4.90958814e-02  4.05616183e-02
#    1.76209209e-01]
#  [ 6.97799418e-01 -6.97799418e-01 -2.58215062e-02  2.58215062e-02
#   -2.94232370e-02  2.94232370e-02  6.10831976e-02 -6.10831976e-02
#   -3.24887239e-02  3.24887239e-02 -3.38771496e-02  9.24393188e-03
#    2.46332177e-02 -7.43020318e-02  6.58033095e-03  6.77217009e-02
#    3.63934800e-03 -1.20533824e-02  3.14402326e-02  1.05023091e-03
#    2.26667191e-03 -1.08038499e-02  6.74973690e-03  2.19683818e-03
#   -2.53513681e-03 -5.61454463e-03 -8.90017750e-03  1.45663122e-04
# ...

# %%
pc.encoder = OrdinalEncoder()
pc.study_case()

# %%
PCAStudy.combined_study(pc,pc2)
# Out:
#            ENCODER ORIGINAL_FEATURES ENCODED_FEATURES NUMERICAL_TRANSFORMER  \
# 0  OneHotEncoder()                20               29        MinMaxScaler()
# 0  OneHotEncoder()                20               29      StandardScaler()
#
#   PCA_COMPONENTS ORIGINAL_VARIANCE_RETAINED
# 0              2                   0.503329
# 0              2                    0.30044
